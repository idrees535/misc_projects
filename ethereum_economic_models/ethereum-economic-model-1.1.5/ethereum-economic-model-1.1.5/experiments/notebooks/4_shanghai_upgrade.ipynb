# %% [markdown]
# # Experiment Notebook: {Descriptive Experiment Keywords}

# %% [markdown]
# # Table of Contents
# * [Experiment Summary](#Experiment-Summary)
# * [Experiment Assumptions](#Experiment-Assumptions)
# * [Experiment Setup](#Experiment-Setup)
# * [Analysis 1: ...](#Analysis-1:-...)

# %% [markdown]
# # Experiment Summary
#
# The purpose of this notebook is to...
#
# # Experiment Assumptions
#
# See [assumptions document](../../ASSUMPTIONS.md) for further details.

# %% [markdown]
# # Experiment Setup
#
# We begin with several experiment-notebook-level preparatory setup operations:
#
# * Import relevant dependencies
# * Import relevant experiment templates
# * Create copies of experiments
# * Configure and customize experiments
#
# Analysis-specific setup operations are handled in their respective notebook sections.

# %%
# Import the setup module:
# * sets up the Python path
# * runs shared notebook configuration methods, such as loading IPython modules
import setup

import copy
import logging
import numpy as np
import pandas as pd
import plotly.express as px

import experiments.notebooks.visualizations as visualizations
from experiments.run import run
from experiments.utils import display_code
# Out:
# time: 125 ms (started: 2023-03-20 21:42:22 +05:00)

# %%
# Enable/disable logging
logger = logging.getLogger()
logger.disabled = False
# Out:
# time: 109 ms (started: 2023-03-20 21:42:22 +05:00)

# %%
# Import experiment templates
import experiments.default_experiment as default_experiment
import experiments.templates.eth_unstaking as eth_unstaking
# Out:
# time: 125 ms (started: 2023-03-20 21:42:22 +05:00)

# %%
# Inspect experiment template
display_code(eth_unstaking)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .highlight .hll { background-color: #ffffcc }
# .highlight { background: #f8f8f8; }
# .highlight .c { color: #3D7B7B; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #9C6500 } /* Comment.Preproc */
# .highlight .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #E40000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #008400 } /* Generic.Inserted */
# .highlight .go { color: #717171 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #687822 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #767600 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #A45A77 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style>
# """
# # Experiment template example
#
# An example of overriding and customizing the default experiment to create a new template.
# """
#
# import copy
# import numpy as np
#
# from experiments.default_experiment import experiment
# from experiments.simulation_configuration import TIMESTEPS, DELTA_TIME
# from model.state_variables import eth_staked, eth_supply, eth_price_max
# from experiments.default_experiment import experiment
#
# # Make a copy of the default experiment to avoid mutation
# experiment = copy.deepcopy(experiment)
#
# eth_staked_samples = np.linspace(
#     eth_staked,
#     eth_supply * 0.3,  # 30% of current total ETH supply
#     50
# )
#
# parameter_overrides = {
#     "eth_staked_process": [
#         lambda run, _timestep: eth_staked_samples[run - 1],
#     ],
#     "eth_price_process": [
#         # A sweep of two fixed ETH price points
#         lambda _run, _timestep: 1000,
#         lambda _run, _timestep: eth_price_max,
#     ]
# }
#
# # Override default experiment parameters
# experiment.simulations[0].model.params.update(parameter_overrides)
# # Set runs to number of items in eth_staked_samples
# experiment.simulations[0].runs = len(eth_staked_samples)
# # Run single timestep, set unit of time to multiple epochs
# experiment.simulations[0].timesteps = 1
# experiment.simulations[0].model.params.update({"dt": [TIMESTEPS * DELTA_TIME]})
# time: 141 ms (started: 2023-03-20 21:42:22 +05:00)

# %%
# Create a simulation for each analysis
simulation_1 = copy.deepcopy(eth_unstaking.experiment.simulations[0])
# Out:
# time: 125 ms (started: 2023-03-20 21:42:23 +05:00)

# %%
# Experiment configuration
from model.types import Stage
simulation_1.model.params.update({
    "stage": [Stage.PROOF_OF_STAKE]
})
# Out:
# time: 110 ms (started: 2023-03-20 21:42:23 +05:00)

# %% [markdown]
# # Analysis 1: ...

# %% [markdown]
# {Analysis Description}

# %%
# Analysis-specific setup
# Out:
# time: 156 ms (started: 2023-03-20 21:42:23 +05:00)

# %%
# Experiment execution
df, exceptions = run(simulation_1)
# Out:
# 2023-03-20 21:42:23,926 - root - INFO - Running experiment
# 2023-03-20 21:42:23,930 - root - INFO - Starting simulation 0 / run 0 / subset 0
# 2023-03-20 21:42:23,933 - root - INFO - Starting simulation 0 / run 0 / subset 1
# 2023-03-20 21:42:23,936 - root - INFO - Starting simulation 0 / run 1 / subset 0
# 2023-03-20 21:42:23,936 - root - INFO - Starting simulation 0 / run 1 / subset 1
# 2023-03-20 21:42:23,936 - root - INFO - Starting simulation 0 / run 2 / subset 0
# 2023-03-20 21:42:23,943 - root - INFO - Starting simulation 0 / run 2 / subset 1
# 2023-03-20 21:42:23,943 - root - INFO - Starting simulation 0 / run 3 / subset 0
# 2023-03-20 21:42:23,948 - root - INFO - Starting simulation 0 / run 3 / subset 1
# 2023-03-20 21:42:23,951 - root - INFO - Starting simulation 0 / run 4 / subset 0
# 2023-03-20 21:42:23,951 - root - INFO - Starting simulation 0 / run 4 / subset 1
# 2023-03-20 21:42:23,951 - root - INFO - Starting simulation 0 / run 5 / subset 0
# 2023-03-20 21:42:23,959 - root - INFO - Starting simulation 0 / run 5 / subset 1
# 2023-03-20 21:42:23,959 - root - INFO - Starting simulation 0 / run 6 / subset 0
# 2023-03-20 21:42:23,959 - root - INFO - Starting simulation 0 / run 6 / subset 1
# 2023-03-20 21:42:23,967 - root - INFO - Starting simulation 0 / run 7 / subset 0
# 2023-03-20 21:42:23,969 - root - INFO - Starting simulation 0 / run 7 / subset 1
# 2023-03-20 21:42:23,975 - root - INFO - Starting simulation 0 / run 8 / subset 0
# 2023-03-20 21:42:23,979 - root - INFO - Starting simulation 0 / run 8 / subset 1
# 2023-03-20 21:42:23,984 - root - INFO - Starting simulation 0 / run 9 / subset 0
# 2023-03-20 21:42:23,987 - root - INFO - Starting simulation 0 / run 9 / subset 1
# 2023-03-20 21:42:23,990 - root - INFO - Starting simulation 0 / run 10 / subset 0
# 2023-03-20 21:42:23,993 - root - INFO - Starting simulation 0 / run 10 / subset 1
# 2023-03-20 21:42:23,994 - root - INFO - Starting simulation 0 / run 11 / subset 0
# 2023-03-20 21:42:24,001 - root - INFO - Starting simulation 0 / run 11 / subset 1
# 2023-03-20 21:42:24,004 - root - INFO - Starting simulation 0 / run 12 / subset 0
# 2023-03-20 21:42:24,008 - root - INFO - Starting simulation 0 / run 12 / subset 1
# 2023-03-20 21:42:24,011 - root - INFO - Starting simulation 0 / run 13 / subset 0
# 2023-03-20 21:42:24,015 - root - INFO - Starting simulation 0 / run 13 / subset 1
# 2023-03-20 21:42:24,015 - root - INFO - Starting simulation 0 / run 14 / subset 0
# 2023-03-20 21:42:24,023 - root - INFO - Starting simulation 0 / run 14 / subset 1
# 2023-03-20 21:42:24,023 - root - INFO - Starting simulation 0 / run 15 / subset 0
# 2023-03-20 21:42:24,023 - root - INFO - Starting simulation 0 / run 15 / subset 1
# 2023-03-20 21:42:24,031 - root - INFO - Starting simulation 0 / run 16 / subset 0
# 2023-03-20 21:42:24,032 - root - INFO - Starting simulation 0 / run 16 / subset 1
# 2023-03-20 21:42:24,039 - root - INFO - Starting simulation 0 / run 17 / subset 0
# 2023-03-20 21:42:24,041 - root - INFO - Starting simulation 0 / run 17 / subset 1
# 2023-03-20 21:42:24,041 - root - INFO - Starting simulation 0 / run 18 / subset 0
# 2023-03-20 21:42:24,047 - root - INFO - Starting simulation 0 / run 18 / subset 1
# 2023-03-20 21:42:24,049 - root - INFO - Starting simulation 0 / run 19 / subset 0
# 2023-03-20 21:42:24,051 - root - INFO - Starting simulation 0 / run 19 / subset 1
# 2023-03-20 21:42:24,057 - root - INFO - Starting simulation 0 / run 20 / subset 0
# 2023-03-20 21:42:24,060 - root - INFO - Starting simulation 0 / run 20 / subset 1
# 2023-03-20 21:42:24,064 - root - INFO - Starting simulation 0 / run 21 / subset 0
# 2023-03-20 21:42:24,067 - root - INFO - Starting simulation 0 / run 21 / subset 1
# 2023-03-20 21:42:24,067 - root - INFO - Starting simulation 0 / run 22 / subset 0
# 2023-03-20 21:42:24,075 - root - INFO - Starting simulation 0 / run 22 / subset 1
# 2023-03-20 21:42:24,075 - root - INFO - Starting simulation 0 / run 23 / subset 0
# 2023-03-20 21:42:24,081 - root - INFO - Starting simulation 0 / run 23 / subset 1
# 2023-03-20 21:42:24,081 - root - INFO - Starting simulation 0 / run 24 / subset 0
# 2023-03-20 21:42:24,081 - root - INFO - Starting simulation 0 / run 24 / subset 1
# 2023-03-20 21:42:24,081 - root - INFO - Starting simulation 0 / run 25 / subset 0
# 2023-03-20 21:42:24,093 - root - INFO - Starting simulation 0 / run 25 / subset 1
# 2023-03-20 21:42:24,097 - root - INFO - Starting simulation 0 / run 26 / subset 0
# 2023-03-20 21:42:24,098 - root - INFO - Starting simulation 0 / run 26 / subset 1
# 2023-03-20 21:42:24,107 - root - INFO - Starting simulation 0 / run 27 / subset 0
# 2023-03-20 21:42:24,107 - root - INFO - Starting simulation 0 / run 27 / subset 1
# 2023-03-20 21:42:24,114 - root - INFO - Starting simulation 0 / run 28 / subset 0
# 2023-03-20 21:42:24,114 - root - INFO - Starting simulation 0 / run 28 / subset 1
# 2023-03-20 21:42:24,121 - root - INFO - Starting simulation 0 / run 29 / subset 0
# 2023-03-20 21:42:24,121 - root - INFO - Starting simulation 0 / run 29 / subset 1
# 2023-03-20 21:42:24,129 - root - INFO - Starting simulation 0 / run 30 / subset 0
# 2023-03-20 21:42:24,131 - root - INFO - Starting simulation 0 / run 30 / subset 1
# 2023-03-20 21:42:24,134 - root - INFO - Starting simulation 0 / run 31 / subset 0
# 2023-03-20 21:42:24,138 - root - INFO - Starting simulation 0 / run 31 / subset 1
# 2023-03-20 21:42:24,138 - root - INFO - Starting simulation 0 / run 32 / subset 0
# 2023-03-20 21:42:24,138 - root - INFO - Starting simulation 0 / run 32 / subset 1
# 2023-03-20 21:42:24,145 - root - INFO - Starting simulation 0 / run 33 / subset 0
# 2023-03-20 21:42:24,145 - root - INFO - Starting simulation 0 / run 33 / subset 1
# 2023-03-20 21:42:24,152 - root - INFO - Starting simulation 0 / run 34 / subset 0
# 2023-03-20 21:42:24,153 - root - INFO - Starting simulation 0 / run 34 / subset 1
# 2023-03-20 21:42:24,157 - root - INFO - Starting simulation 0 / run 35 / subset 0
# 2023-03-20 21:42:24,159 - root - INFO - Starting simulation 0 / run 35 / subset 1
# 2023-03-20 21:42:24,161 - root - INFO - Starting simulation 0 / run 36 / subset 0
# 2023-03-20 21:42:24,165 - root - INFO - Starting simulation 0 / run 36 / subset 1
# 2023-03-20 21:42:24,167 - root - INFO - Starting simulation 0 / run 37 / subset 0
# 2023-03-20 21:42:24,170 - root - INFO - Starting simulation 0 / run 37 / subset 1
# 2023-03-20 21:42:24,173 - root - INFO - Starting simulation 0 / run 38 / subset 0
# 2023-03-20 21:42:24,177 - root - INFO - Starting simulation 0 / run 38 / subset 1
# 2023-03-20 21:42:24,181 - root - INFO - Starting simulation 0 / run 39 / subset 0
# 2023-03-20 21:42:24,181 - root - INFO - Starting simulation 0 / run 39 / subset 1
# 2023-03-20 21:42:24,189 - root - INFO - Starting simulation 0 / run 40 / subset 0
# 2023-03-20 21:42:24,193 - root - INFO - Starting simulation 0 / run 40 / subset 1
# 2023-03-20 21:42:24,193 - root - INFO - Starting simulation 0 / run 41 / subset 0
# 2023-03-20 21:42:24,199 - root - INFO - Starting simulation 0 / run 41 / subset 1
# 2023-03-20 21:42:24,204 - root - INFO - Starting simulation 0 / run 42 / subset 0
# 2023-03-20 21:42:24,208 - root - INFO - Starting simulation 0 / run 42 / subset 1
# 2023-03-20 21:42:24,210 - root - INFO - Starting simulation 0 / run 43 / subset 0
# 2023-03-20 21:42:24,210 - root - INFO - Starting simulation 0 / run 43 / subset 1
# 2023-03-20 21:42:24,210 - root - INFO - Starting simulation 0 / run 44 / subset 0
# 2023-03-20 21:42:24,219 - root - INFO - Starting simulation 0 / run 44 / subset 1
# 2023-03-20 21:42:24,222 - root - INFO - Starting simulation 0 / run 45 / subset 0
# 2023-03-20 21:42:24,222 - root - INFO - Starting simulation 0 / run 45 / subset 1
# 2023-03-20 21:42:24,222 - root - INFO - Starting simulation 0 / run 46 / subset 0
# 2023-03-20 21:42:24,229 - root - INFO - Starting simulation 0 / run 46 / subset 1
# 2023-03-20 21:42:24,229 - root - INFO - Starting simulation 0 / run 47 / subset 0
# 2023-03-20 21:42:24,234 - root - INFO - Starting simulation 0 / run 47 / subset 1
# 2023-03-20 21:42:24,237 - root - INFO - Starting simulation 0 / run 48 / subset 0
# 2023-03-20 21:42:24,237 - root - INFO - Starting simulation 0 / run 48 / subset 1
# 2023-03-20 21:42:24,237 - root - INFO - Starting simulation 0 / run 49 / subset 0
# 2023-03-20 21:42:24,244 - root - INFO - Starting simulation 0 / run 49 / subset 1
# 2023-03-20 21:42:24,246 - root - INFO - Experiment complete in 0.3196573257446289 seconds
# 2023-03-20 21:42:24,246 - root - INFO - Post-processing results
# 2023-03-20 21:42:24,553 - root - INFO - Post-processing complete in 0.30747294425964355 seconds
# time: 750 ms (started: 2023-03-20 21:42:23 +05:00)

# %%
# Post-processing and visualizations
df
# Out:
#      stage                  timestamp  eth_price    eth_supply    eth_staked  \
# 1      4.0 2023-03-20 21:25:10.770249    1000.00  1.218782e+08  1.878644e+07
# 3      4.0 2023-03-20 21:25:10.770249    4181.28  1.218782e+08  1.878644e+07
# 5      4.0 2023-03-20 21:25:10.770249    1000.00  1.218854e+08  1.915227e+07
# 7      4.0 2023-03-20 21:25:10.770249    4181.28  1.218854e+08  1.915227e+07
# 9      4.0 2023-03-20 21:25:10.770249    1000.00  1.218924e+08  1.951810e+07
# ..     ...                        ...        ...           ...           ...
# 191    4.0 2023-03-20 21:25:10.770249    4181.28  1.221365e+08  3.598050e+07
# 193    4.0 2023-03-20 21:25:10.770249    1000.00  1.221404e+08  3.634633e+07
# 195    4.0 2023-03-20 21:25:10.770249    4181.28  1.221404e+08  3.634633e+07
# 197    4.0 2023-03-20 21:25:10.770249    1000.00  1.221470e+08  3.671216e+07
# 199    4.0 2023-03-20 21:25:10.770249    4181.28  1.221470e+08  3.671216e+07
#
#      supply_inflation  network_issuance  pow_issuance  \
# 1           -0.004109    -495641.450716             0
# 3           -0.004109    -495641.450716             0
# 5           -0.004050    -488449.239405             0
# 7           -0.004050    -488449.239405             0
# 9           -0.003992    -481480.149231             0
# ..                ...               ...           ...
# 191         -0.001968    -237348.874370             0
# 193         -0.001936    -233472.517478             0
# 195         -0.001936    -233472.517478             0
# 197         -0.001881    -226895.288202             0
# 199         -0.001881    -226895.288202             0
#
#      number_of_validators_in_activation_queue  average_effective_balance  ...  \
# 1                                           0               3.200000e+10  ...
# 3                                           0               3.200000e+10  ...
# 5                                           0               3.200000e+10  ...
# 7                                           0               3.200000e+10  ...
# 9                                           0               3.199998e+10  ...
# ..                                        ...                        ...  ...
# 191                                         0               3.199999e+10  ...
# 193                                         0               3.199999e+10  ...
# 195                                         0               3.199999e+10  ...
# 197                                         0               3.200000e+10  ...
# 199                                         0               3.200000e+10  ...
#
#      target_reward_eth  head_reward_eth  block_proposer_reward_eth  \
# 1        276669.169094    148975.706435               86866.301128
# 3        276669.169094    148975.706435               86866.301128
# 5        279635.598678    150573.014673               87797.676194
# 7        279635.598678    150573.014673               87797.676194
# 9        282510.001875    152120.770240               88700.157575
# ..                 ...              ...                        ...
# 191      383202.015071    206339.546577              120314.604418
# 193      384800.819567    207200.441305              120816.583852
# 195      384800.819567    207200.441305              120816.583852
# 197      387513.599641    208661.169037              121668.320138
# 199      387513.599641    208661.169037              121668.320138
#
#      sync_reward_eth  whistleblower_rewards_eth  amount_slashed_eth  \
# 1       21716.575282                   5.062500           40.500000
# 3       21716.575282                   5.062500           40.500000
# 5       21949.419048                   5.062500           40.500000
# 7       21949.419048                   5.062500           40.500000
# 9       22175.039394                   5.062496           40.499969
# ..               ...                        ...                 ...
# 191     30078.651104                   5.062498           40.499983
# 193     30204.145963                   5.062499           40.499991
# 195     30204.145963                   5.062499           40.499991
# 197     30417.080035                   5.062500           40.499999
# 199     30417.080035                   5.062500           40.499999
#
#      daily_revenue_yields_pct  cumulative_revenue_yields_pct  \
# 1                    3.984572                       3.984572
# 3                    3.984572                       3.984572
# 5                    3.946015                       7.930587
# 7                    3.946015                       7.930587
# 9                    3.907760                      11.838346
# ..                        ...                            ...
# 191                  2.798326                     158.103823
# 193                  2.780826                     160.884649
# 195                  2.780826                     160.884649
# 197                  2.771031                     163.655679
# 199                  2.771031                     163.655679
#
#      daily_profit_yields_pct  cumulative_profit_yields_pct
# 1                   3.613657                      3.613657
# 3                   3.732156                      3.732156
# 5                   3.577182                      7.190839
# 7                   3.695681                      7.427837
# 9                   3.540993                     10.731832
# ..                       ...                           ...
# 191                 2.609968                    147.778273
# 193                 2.474913                    144.565235
# 195                 2.593412                    150.371685
# 197                 2.465647                    147.030882
# 199                 2.584146                    152.955831
#
# [100 rows x 156 columns]
# time: 266 ms (started: 2023-03-20 21:42:24 +05:00)
